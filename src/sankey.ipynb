# %%
import pnet_loader
import util
import Pnet
import ReactomeNetwork
import torch
import random
import seaborn as sns
import pandas as pd
import os
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.svm import SVC
import torch.nn.functional as F
import torch.nn as nn
import plotly.graph_objects as go
import sankey_diag

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
imps_dir = '/mnt/disks/pancan/pnet/results/prostate_val/run0/'
savepath = '/mnt/disks/pancan/pnet/figures/prostate_sankey_diagram.html'
sk = sankey_diag.SankeyDiag(imps_dir)
sk.get_sankey_diag(savepath)

# %%
imps_dir = '/mnt/disks/pancan/pnet/results/ploidy/liu_val_skcm/run0/'
savepath = '/mnt/disks/pancan/pnet/figures/ploidy_liu_sankey_diagram.html'
sk = sankey_diag.SankeyDiag(imps_dir)
sk.get_sankey_diag(savepath)

# %%
imps_dir = '/mnt/disks/pancan/pnet/results/ploidy/tcga_skcm/run0/'
savepath = '/mnt/disks/pancan/pnet/figures/ploidy_tcga_sankey_diagram.html'
sk = sankey_diag.SankeyDiag(imps_dir)
sk.get_sankey_diag(savepath)
